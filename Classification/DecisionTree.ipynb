# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import model_selection
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# ## Q-1: Load the dataset and print the metadata in the notebook

# %%
data = pd.read_csv("loan_data.csv")

# %%
data.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
data.describe()
# Out:
#        credit.policy     int.rate  installment  log.annual.inc          dti  \
# count    9578.000000  9578.000000  9578.000000     9578.000000  9578.000000
# mean        0.804970     0.122640   319.089413       10.932117    12.606679
# std         0.396245     0.026847   207.071301        0.614813     6.883970
# min         0.000000     0.060000    15.670000        7.547502     0.000000
# 25%         1.000000     0.103900   163.770000       10.558414     7.212500
# 50%         1.000000     0.122100   268.950000       10.928884    12.665000
# 75%         1.000000     0.140700   432.762500       11.291293    17.950000
# max         1.000000     0.216400   940.140000       14.528354    29.960000
#
#               fico  days.with.cr.line     revol.bal   revol.util  \
# count  9578.000000        9578.000000  9.578000e+03  9578.000000
# mean    710.846314        4560.767197  1.691396e+04    46.799236
# std      37.970537        2496.930377  3.375619e+04    29.014417
# ...

# %% [markdown]
# ## Q-2: Create a countplot using sns showing the counts of loans by purpose,  with the color hue defined by not.fully.paid.

# %%
plt.subplots(figsize = (12,6))
sns.countplot(x = 'purpose', hue = 'not.fully.paid', data = data)

# %%
plt.figure(figsize=(20,10))
h = data.corr()
sns.heatmap(h,cmap="BrBG", annot=True)

# %% [markdown]
# ## Q-3: Print a heatmap to check NULL values.

# %%
sns.heatmap(data.isnull(), cbar=False)

# %%
categorical_attributes = ['purpose']
processed_data = pd.get_dummies(data, columns = categorical_attributes, drop_first = True)

# %%
X = processed_data.drop('not.fully.paid', axis = 1)
y = processed_data['not.fully.paid']

# %% [markdown]
# ## Q-4: Perform startified splitting of train and test data.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.25)

# %%
decision_tree = DecisionTreeClassifier()

# %% [markdown]
# ## Q-5: Build a classifier model using Decision Tree algorithm and plot the  same.

# %%
classifier = decision_tree.fit(X_train, y_train)

# %%
y_predict = decision_tree.predict(X_test)

# %%
fig = plt.figure(figsize=(80,20))
_ = tree.plot_tree(classifier, max_depth= 3, filled=True)

# %% [markdown]
# ## Q-6: Print classification report.

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.84      0.85      2012
#            1       0.22      0.23      0.23       383
#
#     accuracy                           0.75      2395
#    macro avg       0.54      0.54      0.54      2395
# weighted avg       0.75      0.75      0.75      2395

# %% [markdown]
# ## Q-7: Find out the stratified cross validation accuracy

# %%
skfold = StratifiedKFold(n_splits=5)
results_skfold = model_selection.cross_val_score(decision_tree, X, y, cv=skfold)

# %%
print(results_skfold)
# Out:
# [0.74373695 0.74530271 0.76304802 0.73942559 0.27206266]
